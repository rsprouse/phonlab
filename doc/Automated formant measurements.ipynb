# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Automated formant measurements
#
# This notebook illustrates how to run several formant trackers on a corpus of audio files and collect the results in order to do ensemble analysis. The ensemble technique involves generating formant estimates using several different algorithms, then choosing the best fit.
#
# The X-Ray Microbeam database will be used for the illustration. This database contains audio and associated articulatory data from 48 speakers. Aligned word and phone labels for the audio are available separately.
#
# In this notebook we generate and cache three formant estimates with (1) the inverse filter control method using `ifcformant` and via LPC analysis with the ESPS `formant` command's (2) covariance and (3) autocorrelation modes.
#
# There are three sources of background information that will make it easier to follow this notebook, and it is recommended that you consult them if you are lost are want more detail.
#
# 1. The [Post-processing and data collection notebook](https://github.com/rsprouse/phonlab/blob/master/doc/post-processing_and_data_collection.ipynb) illustrates the post-processing workflow employed in this notebook.
# 2. The [`dir2df()` notebook](https://github.com/rsprouse/phonlab/blob/master/doc/Retrieving%20filenames%20in%20a%20directory%20tree%20with%20%60dir2df%28%29%60.ipynb) goes into more detail on the `dir2df()` function, which is used in the post-processing notebook.
# 1. The [X-Ray Microbeam Database repo](https://github.com/rsprouse/xray_microbeam_database) provides the annotations to the X-Ray Microbeam Database and links to the original data files.

# %% [markdown]
# ## The workflow
#
# The general workflow for processing files is as follows:
#
# 1. Read the input data filenames (*.wav) into a DataFrame.
# 1. Mirror the source directory structure in the destination directory.
# 1. Merge input and output filenames to find input files that don't have a corresponding output file.
# 1. Read existing post-processed formant output filenames, if any, into a DataFrame.
# 1. Run the formant analysis for each input file that is missing an output and cache the results.
#
# The steps will be illustrated separately for each of the formant analysis methods.

# %%
import os, re
import subprocess
import pandas as pd
from phonlab.utils import dir2df
from temputils import fb2df

# %% [markdown]
# First we define file locations. The name of the directory containing the microbeam database files is stored in `xraydir`, and three additional cache directories names are stored in `ifcdir`, `covdir`, and `acdir`. These cache directories are where output files for each of the analysis methods will be saved.

# %%
xraydir = '/media/sf_Downloads/xray_microbeam_database'
ifcdir = '/media/sf_Downloads/xray_formants_ifc'  # For ifcformant output files
covdir = '/media/sf_Downloads/xray_formants_cov'  # For covariance method output files
acdir = '/media/sf_Downloads/xray_formants_ac'    # For autocorrelation method output files
#rbdir = '/Users/ronald/Downloads/xray_formants_rb'    # For robust lpc method output files
#analysis = pd.DataFrame.from_records([
#    {'method': 'ifc', 'dir': '/Users/ronald/Downloads/xray_formants_ifc', 'func': run_ifcformant},
#    {'method': 'cov', 'dir': '/Users/ronald/Downloads/xray_formants_cov', 'func': run_formant_cov},
#    {'method': 'ac', 'dir': '/Users/ronald/Downloads/xray_formants_ac', 'func': run_formant_ac},
#    {'method': 'rb', 'dir': '/Users/ronald/Downloads/xray_formants_rb', 'func': run_robustlpc},
#])
#analysis

# %% [markdown]
# ## Load speaker metadata
#
# Speaker metadata for the xray database is found in the 'speaker_metadata.csv' file. Use the `read_csv()` function to read the 'subject' and 'sex' columns from it. The .csv file uses 'F' and 'M' in the 'sex' column, and the `converters` parameter replaces these values with 'female' and 'male', which are values compatible with `ifcformant`.

# %%
md = pd.read_csv(
    os.path.join(xraydir, 'speaker_metadata.csv'),
    usecols=['subject', 'sex'],
    converters={'sex': lambda x: 'female' if x == 'F' else 'male'}
)
md.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-b25032bad44d> in <module>()
#       2     os.path.join(xraydir, 'speaker_metadata.csv'),
#       3     usecols=['subject', 'sex'],
# ----> 4     converters={'sex': lambda x: 'female' if x == 'F' else 'male'}
#       5 )
#       6 md.head()
#
# /Users/ronald/anaconda3/lib/python3.6/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skipfooter, skip_footer, doublequote, delim_whitespace, as_recarray, compact_ints, use_unsigned, low_memory, buffer_lines, memory_map, float_precision)
#     707                     skip_blank_lines=skip_blank_lines)
#     708
# --> 709         return _read(filepath_or_buffer, kwds)
#     710
#     711     parser_f.__name__ = name
#
# /Users/ronald/anaconda3/lib/python3.6/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     447
#     448     # Create the parser.
# --> 449     parser = TextFileReader(filepath_or_buffer, **kwds)
#     450
#     451     if chunksize or iterator:
#
# /Users/ronald/anaconda3/lib/python3.6/site-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     816             self.options['has_index_names'] = kwds['has_index_names']
#     817
# --> 818         self._make_engine(self.engine)
#     819
#     820     def close(self):
#
# /Users/ronald/anaconda3/lib/python3.6/site-packages/pandas/io/parsers.py in _make_engine(self, engine)
#    1047     def _make_engine(self, engine='c'):
#    1048         if engine == 'c':
# -> 1049             self._engine = CParserWrapper(self.f, **self.options)
#    1050         else:
#    1051             if engine == 'python':
#
# /Users/ronald/anaconda3/lib/python3.6/site-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    1693         kwds['allow_leading_cols'] = self.index_col is not False
#    1694
# -> 1695         self._reader = parsers.TextReader(src, **kwds)
#    1696
#    1697         # XXX
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: File b'/media/sf_Downloads/xray_microbeam_database/speaker_metadata.csv' does not exist

# %% [markdown]
# Add lpc analysis parameters based on sex. The values are defined as strings since they will be used for command line arguments rather than for calculations or comparisons.

# %%
lpcargs = pd.DataFrame.from_records([
    ('female', '12', '600'),
    ('male',   '14', '500'),
    ('child',  '10', '700')
], columns=['sex', 'lpc_order', 'nom_f1'])
lpcargs
# Out:
#       sex lpc_order nom_f1
# 0  female        12    600
# 1    male        14    500
# 2   child        10    700

# %%
md = md.merge(lpcargs, on='sex', how='left')
md.head()
# Out:
#   subject     sex lpc_order nom_f1
# 0    JW05  female        12    600
# 1    JW06    male        14    500
# 2    JW07    male        14    500
# 3    JW08    male        14    500
# 4    JW09  female        12    600

# %% [markdown]
# # Load xray filenames
#
# Load the .wav files in the xray database.

# %%
wavdf = dir2df(
    xraydir,
    dirpat='^JW',
    fnpat='\.wav$',
#    fnpat='^tp(?P<task>\d+)\.wav$',  # also include ta*.wav?
    addcols=['dirname', 'barename']
)
wavdf.head()
# Out:
#                                            dirname relpath      fname barename
# 0  /Users/ronald/Downloads/xray_microbeam_database    JW11  ta001.wav    ta001
# 1  /Users/ronald/Downloads/xray_microbeam_database    JW11  ta002.wav    ta002
# 2  /Users/ronald/Downloads/xray_microbeam_database    JW11  ta003.wav    ta003
# 3  /Users/ronald/Downloads/xray_microbeam_database    JW11  ta004.wav    ta004
# 4  /Users/ronald/Downloads/xray_microbeam_database    JW11  ta005.wav    ta005

# %% [markdown]
# ## Ensure destination directories are created
#
# Output files will be written to a directory structure that is like the one found in the xray data directory. The next cell creates the subdirectories of `xraydir` in `formantdir` if they don't already exist, in preparation for writing formant analysis output files.
#
# The `os.makedirs()` function automatically creates intermediate directories if necessary for nested subdirectories. Setting the `exist_ok` parameter to `True` makes it safe to use this function without checking whether any of the destination directories already exist (by default `os.makedirs()` will throw an `OSError` if you attempt to re-create an existing directory), which means you can safely use the following loop to keep a destination directory in sync incrementally with a data directory as more data is added.

# %%
for d in wavdf.relpath.unique():
    os.makedirs(os.path.join(ifcdir, d), exist_ok=True)

# %% [markdown]
# ## Merge with speaker metadata.

# %%
wavdf = wavdf.merge(
    md,
    left_on='relpath',
    right_on='subject',
    how='left'
)
wavdf
# Out:
#                                               dirname relpath        fname  \
# 0     /Users/ronald/Downloads/xray_microbeam_database    JW11    ta001.wav
# 1     /Users/ronald/Downloads/xray_microbeam_database    JW11    ta002.wav
# 2     /Users/ronald/Downloads/xray_microbeam_database    JW11    ta003.wav
# 3     /Users/ronald/Downloads/xray_microbeam_database    JW11    ta004.wav
# 4     /Users/ronald/Downloads/xray_microbeam_database    JW11    ta005.wav
# 5     /Users/ronald/Downloads/xray_microbeam_database    JW11    ta006.wav
# 6     /Users/ronald/Downloads/xray_microbeam_database    JW11    ta007.wav
# 7     /Users/ronald/Downloads/xray_microbeam_database    JW11    ta008.wav
# 8     /Users/ronald/Downloads/xray_microbeam_database    JW11    ta009.wav
# 9     /Users/ronald/Downloads/xray_microbeam_database    JW11    ta010.wav
# 10    /Users/ronald/Downloads/xray_microbeam_database    JW11    ta011.wav
# 11    /Users/ronald/Downloads/xray_microbeam_database    JW11    ta012.wav
# 12    /Users/ronald/Downloads/xray_microbeam_database    JW11    ta013.wav
# 13    /Users/ronald/Downloads/xray_microbeam_database    JW11    ta014.wav
# 14    /Users/ronald/Downloads/xray_microbeam_database    JW11    ta015.wav
# 15    /Users/ronald/Downloads/xray_microbeam_database    JW11    ta018.wav
# 16    /Users/ronald/Downloads/xray_microbeam_database    JW11    ta019.wav
# 17    /Users/ronald/Downloads/xray_microbeam_database    JW11    tp001.wav
# 18    /Users/ronald/Downloads/xray_microbeam_database    JW11    tp002.wav
# 19    /Users/ronald/Downloads/xray_microbeam_database    JW11    tp003.wav
# 20    /Users/ronald/Downloads/xray_microbeam_database    JW11    tp004.wav
# 21    /Users/ronald/Downloads/xray_microbeam_database    JW11    tp005.wav
# 22    /Users/ronald/Downloads/xray_microbeam_database    JW11    tp006.wav
# 23    /Users/ronald/Downloads/xray_microbeam_database    JW11    tp007.wav
# 24    /Users/ronald/Downloads/xray_microbeam_database    JW11    tp008.wav
# 25    /Users/ronald/Downloads/xray_microbeam_database    JW11    tp009.wav
# 26    /Users/ronald/Downloads/xray_microbeam_database    JW11    tp010.wav
# 27    /Users/ronald/Downloads/xray_microbeam_database    JW11    tp011.wav
# 28    /Users/ronald/Downloads/xray_microbeam_database    JW11    tp012.wav
# 29    /Users/ronald/Downloads/xray_microbeam_database    JW11    tp013.wav
# ...                                               ...     ...          ...
# 6519  /Users/ronald/Downloads/xray_microbeam_database    JW63    tp092.wav
# 6520  /Users/ronald/Downloads/xray_microbeam_database    JW63    tp093.wav
# 6521  /Users/ronald/Downloads/xray_microbeam_database    JW63    tp094.wav
# 6522  /Users/ronald/Downloads/xray_microbeam_database    JW63    tp095.wav
# 6523  /Users/ronald/Downloads/xray_microbeam_database    JW63    tp096.wav
# 6524  /Users/ronald/Downloads/xray_microbeam_database    JW63    tp097.wav
# 6525  /Users/ronald/Downloads/xray_microbeam_database    JW63    tp098.wav
# 6526  /Users/ronald/Downloads/xray_microbeam_database    JW63    tp099.wav
# 6527  /Users/ronald/Downloads/xray_microbeam_database    JW63    tp100.wav
# 6528  /Users/ronald/Downloads/xray_microbeam_database    JW63    tp101.wav
# 6529  /Users/ronald/Downloads/xray_microbeam_database    JW63    tp102.wav
# 6530  /Users/ronald/Downloads/xray_microbeam_database    JW63  tp102_2.wav
# 6531  /Users/ronald/Downloads/xray_microbeam_database    JW63    tp103.wav
# 6532  /Users/ronald/Downloads/xray_microbeam_database    JW63  tp103_2.wav
# 6533  /Users/ronald/Downloads/xray_microbeam_database    JW63  tp104_2.wav
# 6534  /Users/ronald/Downloads/xray_microbeam_database    JW63    tp105.wav
# 6535  /Users/ronald/Downloads/xray_microbeam_database    JW63    tp106.wav
# 6536  /Users/ronald/Downloads/xray_microbeam_database    JW63    tp107.wav
# 6537  /Users/ronald/Downloads/xray_microbeam_database    JW63    tp108.wav
# 6538  /Users/ronald/Downloads/xray_microbeam_database    JW63    tp109.wav
# 6539  /Users/ronald/Downloads/xray_microbeam_database    JW63    tp110.wav
# 6540  /Users/ronald/Downloads/xray_microbeam_database    JW63    tp111.wav
# 6541  /Users/ronald/Downloads/xray_microbeam_database    JW63    tp112.wav
# 6542  /Users/ronald/Downloads/xray_microbeam_database    JW63    tp113.wav
# 6543  /Users/ronald/Downloads/xray_microbeam_database    JW63    tp114.wav
# 6544  /Users/ronald/Downloads/xray_microbeam_database    JW63    tp115.wav
# 6545  /Users/ronald/Downloads/xray_microbeam_database    JW63    tp116.wav
# 6546  /Users/ronald/Downloads/xray_microbeam_database    JW63    tp117.wav
# 6547  /Users/ronald/Downloads/xray_microbeam_database    JW63  tp117_2.wav
# 6548  /Users/ronald/Downloads/xray_microbeam_database    JW63    tp118.wav
#
#      barename subject   sex lpc_order nom_f1
# 0       ta001    JW11  male        14    500
# 1       ta002    JW11  male        14    500
# 2       ta003    JW11  male        14    500
# 3       ta004    JW11  male        14    500
# 4       ta005    JW11  male        14    500
# 5       ta006    JW11  male        14    500
# 6       ta007    JW11  male        14    500
# 7       ta008    JW11  male        14    500
# 8       ta009    JW11  male        14    500
# 9       ta010    JW11  male        14    500
# 10      ta011    JW11  male        14    500
# 11      ta012    JW11  male        14    500
# 12      ta013    JW11  male        14    500
# 13      ta014    JW11  male        14    500
# 14      ta015    JW11  male        14    500
# 15      ta018    JW11  male        14    500
# 16      ta019    JW11  male        14    500
# 17      tp001    JW11  male        14    500
# 18      tp002    JW11  male        14    500
# 19      tp003    JW11  male        14    500
# 20      tp004    JW11  male        14    500
# 21      tp005    JW11  male        14    500
# 22      tp006    JW11  male        14    500
# 23      tp007    JW11  male        14    500
# 24      tp008    JW11  male        14    500
# 25      tp009    JW11  male        14    500
# 26      tp010    JW11  male        14    500
# 27      tp011    JW11  male        14    500
# 28      tp012    JW11  male        14    500
# 29      tp013    JW11  male        14    500
# ...       ...     ...   ...       ...    ...
# 6519    tp092    JW63  male        14    500
# 6520    tp093    JW63  male        14    500
# 6521    tp094    JW63  male        14    500
# 6522    tp095    JW63  male        14    500
# 6523    tp096    JW63  male        14    500
# 6524    tp097    JW63  male        14    500
# 6525    tp098    JW63  male        14    500
# 6526    tp099    JW63  male        14    500
# 6527    tp100    JW63  male        14    500
# 6528    tp101    JW63  male        14    500
# 6529    tp102    JW63  male        14    500
# 6530  tp102_2    JW63  male        14    500
# 6531    tp103    JW63  male        14    500
# 6532  tp103_2    JW63  male        14    500
# 6533  tp104_2    JW63  male        14    500
# 6534    tp105    JW63  male        14    500
# 6535    tp106    JW63  male        14    500
# 6536    tp107    JW63  male        14    500
# 6537    tp108    JW63  male        14    500
# 6538    tp109    JW63  male        14    500
# 6539    tp110    JW63  male        14    500
# 6540    tp111    JW63  male        14    500
# 6541    tp112    JW63  male        14    500
# 6542    tp113    JW63  male        14    500
# 6543    tp114    JW63  male        14    500
# 6544    tp115    JW63  male        14    500
# 6545    tp116    JW63  male        14    500
# 6546    tp117    JW63  male        14    500
# 6547  tp117_2    JW63  male        14    500
# 6548    tp118    JW63  male        14    500
#
# [6549 rows x 8 columns]

# %% [markdown]
# ## Add expected file extensions
#
# We expect to find '.ifc', '.fbc', and '.fba' output files for every input '.wav' file. We create columns for each of these extensions that will be used as merge keys when merging with existing output files.

# %%
wavdf = wavdf.assign(ifcext='.ifc')
wavdf
# Out:
#                                               dirname relpath        fname  \
# 0     /Users/ronald/Downloads/xray_microbeam_database    JW11    ta001.wav
# 1     /Users/ronald/Downloads/xray_microbeam_database    JW11    ta002.wav
# 2     /Users/ronald/Downloads/xray_microbeam_database    JW11    ta003.wav
# 3     /Users/ronald/Downloads/xray_microbeam_database    JW11    ta004.wav
# 4     /Users/ronald/Downloads/xray_microbeam_database    JW11    ta005.wav
# 5     /Users/ronald/Downloads/xray_microbeam_database    JW11    ta006.wav
# 6     /Users/ronald/Downloads/xray_microbeam_database    JW11    ta007.wav
# 7     /Users/ronald/Downloads/xray_microbeam_database    JW11    ta008.wav
# 8     /Users/ronald/Downloads/xray_microbeam_database    JW11    ta009.wav
# 9     /Users/ronald/Downloads/xray_microbeam_database    JW11    ta010.wav
# 10    /Users/ronald/Downloads/xray_microbeam_database    JW11    ta011.wav
# 11    /Users/ronald/Downloads/xray_microbeam_database    JW11    ta012.wav
# 12    /Users/ronald/Downloads/xray_microbeam_database    JW11    ta013.wav
# 13    /Users/ronald/Downloads/xray_microbeam_database    JW11    ta014.wav
# 14    /Users/ronald/Downloads/xray_microbeam_database    JW11    ta015.wav
# 15    /Users/ronald/Downloads/xray_microbeam_database    JW11    ta018.wav
# 16    /Users/ronald/Downloads/xray_microbeam_database    JW11    ta019.wav
# 17    /Users/ronald/Downloads/xray_microbeam_database    JW11    tp001.wav
# 18    /Users/ronald/Downloads/xray_microbeam_database    JW11    tp002.wav
# 19    /Users/ronald/Downloads/xray_microbeam_database    JW11    tp003.wav
# 20    /Users/ronald/Downloads/xray_microbeam_database    JW11    tp004.wav
# 21    /Users/ronald/Downloads/xray_microbeam_database    JW11    tp005.wav
# 22    /Users/ronald/Downloads/xray_microbeam_database    JW11    tp006.wav
# 23    /Users/ronald/Downloads/xray_microbeam_database    JW11    tp007.wav
# 24    /Users/ronald/Downloads/xray_microbeam_database    JW11    tp008.wav
# 25    /Users/ronald/Downloads/xray_microbeam_database    JW11    tp009.wav
# 26    /Users/ronald/Downloads/xray_microbeam_database    JW11    tp010.wav
# 27    /Users/ronald/Downloads/xray_microbeam_database    JW11    tp011.wav
# 28    /Users/ronald/Downloads/xray_microbeam_database    JW11    tp012.wav
# 29    /Users/ronald/Downloads/xray_microbeam_database    JW11    tp013.wav
# ...                                               ...     ...          ...
# 6519  /Users/ronald/Downloads/xray_microbeam_database    JW63    tp092.wav
# 6520  /Users/ronald/Downloads/xray_microbeam_database    JW63    tp093.wav
# 6521  /Users/ronald/Downloads/xray_microbeam_database    JW63    tp094.wav
# 6522  /Users/ronald/Downloads/xray_microbeam_database    JW63    tp095.wav
# 6523  /Users/ronald/Downloads/xray_microbeam_database    JW63    tp096.wav
# 6524  /Users/ronald/Downloads/xray_microbeam_database    JW63    tp097.wav
# 6525  /Users/ronald/Downloads/xray_microbeam_database    JW63    tp098.wav
# 6526  /Users/ronald/Downloads/xray_microbeam_database    JW63    tp099.wav
# 6527  /Users/ronald/Downloads/xray_microbeam_database    JW63    tp100.wav
# 6528  /Users/ronald/Downloads/xray_microbeam_database    JW63    tp101.wav
# 6529  /Users/ronald/Downloads/xray_microbeam_database    JW63    tp102.wav
# 6530  /Users/ronald/Downloads/xray_microbeam_database    JW63  tp102_2.wav
# 6531  /Users/ronald/Downloads/xray_microbeam_database    JW63    tp103.wav
# 6532  /Users/ronald/Downloads/xray_microbeam_database    JW63  tp103_2.wav
# 6533  /Users/ronald/Downloads/xray_microbeam_database    JW63  tp104_2.wav
# 6534  /Users/ronald/Downloads/xray_microbeam_database    JW63    tp105.wav
# 6535  /Users/ronald/Downloads/xray_microbeam_database    JW63    tp106.wav
# 6536  /Users/ronald/Downloads/xray_microbeam_database    JW63    tp107.wav
# 6537  /Users/ronald/Downloads/xray_microbeam_database    JW63    tp108.wav
# 6538  /Users/ronald/Downloads/xray_microbeam_database    JW63    tp109.wav
# 6539  /Users/ronald/Downloads/xray_microbeam_database    JW63    tp110.wav
# 6540  /Users/ronald/Downloads/xray_microbeam_database    JW63    tp111.wav
# 6541  /Users/ronald/Downloads/xray_microbeam_database    JW63    tp112.wav
# 6542  /Users/ronald/Downloads/xray_microbeam_database    JW63    tp113.wav
# 6543  /Users/ronald/Downloads/xray_microbeam_database    JW63    tp114.wav
# 6544  /Users/ronald/Downloads/xray_microbeam_database    JW63    tp115.wav
# 6545  /Users/ronald/Downloads/xray_microbeam_database    JW63    tp116.wav
# 6546  /Users/ronald/Downloads/xray_microbeam_database    JW63    tp117.wav
# 6547  /Users/ronald/Downloads/xray_microbeam_database    JW63  tp117_2.wav
# 6548  /Users/ronald/Downloads/xray_microbeam_database    JW63    tp118.wav
#
#      barename subject   sex lpc_order nom_f1 ifcext
# 0       ta001    JW11  male        14    500   .ifc
# 1       ta002    JW11  male        14    500   .ifc
# 2       ta003    JW11  male        14    500   .ifc
# 3       ta004    JW11  male        14    500   .ifc
# 4       ta005    JW11  male        14    500   .ifc
# 5       ta006    JW11  male        14    500   .ifc
# 6       ta007    JW11  male        14    500   .ifc
# 7       ta008    JW11  male        14    500   .ifc
# 8       ta009    JW11  male        14    500   .ifc
# 9       ta010    JW11  male        14    500   .ifc
# 10      ta011    JW11  male        14    500   .ifc
# 11      ta012    JW11  male        14    500   .ifc
# 12      ta013    JW11  male        14    500   .ifc
# 13      ta014    JW11  male        14    500   .ifc
# 14      ta015    JW11  male        14    500   .ifc
# 15      ta018    JW11  male        14    500   .ifc
# 16      ta019    JW11  male        14    500   .ifc
# 17      tp001    JW11  male        14    500   .ifc
# 18      tp002    JW11  male        14    500   .ifc
# 19      tp003    JW11  male        14    500   .ifc
# 20      tp004    JW11  male        14    500   .ifc
# 21      tp005    JW11  male        14    500   .ifc
# 22      tp006    JW11  male        14    500   .ifc
# 23      tp007    JW11  male        14    500   .ifc
# 24      tp008    JW11  male        14    500   .ifc
# 25      tp009    JW11  male        14    500   .ifc
# 26      tp010    JW11  male        14    500   .ifc
# 27      tp011    JW11  male        14    500   .ifc
# 28      tp012    JW11  male        14    500   .ifc
# 29      tp013    JW11  male        14    500   .ifc
# ...       ...     ...   ...       ...    ...    ...
# 6519    tp092    JW63  male        14    500   .ifc
# 6520    tp093    JW63  male        14    500   .ifc
# 6521    tp094    JW63  male        14    500   .ifc
# 6522    tp095    JW63  male        14    500   .ifc
# 6523    tp096    JW63  male        14    500   .ifc
# 6524    tp097    JW63  male        14    500   .ifc
# 6525    tp098    JW63  male        14    500   .ifc
# 6526    tp099    JW63  male        14    500   .ifc
# 6527    tp100    JW63  male        14    500   .ifc
# 6528    tp101    JW63  male        14    500   .ifc
# 6529    tp102    JW63  male        14    500   .ifc
# 6530  tp102_2    JW63  male        14    500   .ifc
# 6531    tp103    JW63  male        14    500   .ifc
# 6532  tp103_2    JW63  male        14    500   .ifc
# 6533  tp104_2    JW63  male        14    500   .ifc
# 6534    tp105    JW63  male        14    500   .ifc
# 6535    tp106    JW63  male        14    500   .ifc
# 6536    tp107    JW63  male        14    500   .ifc
# 6537    tp108    JW63  male        14    500   .ifc
# 6538    tp109    JW63  male        14    500   .ifc
# 6539    tp110    JW63  male        14    500   .ifc
# 6540    tp111    JW63  male        14    500   .ifc
# 6541    tp112    JW63  male        14    500   .ifc
# 6542    tp113    JW63  male        14    500   .ifc
# 6543    tp114    JW63  male        14    500   .ifc
# 6544    tp115    JW63  male        14    500   .ifc
# 6545    tp116    JW63  male        14    500   .ifc
# 6546    tp117    JW63  male        14    500   .ifc
# 6547  tp117_2    JW63  male        14    500   .ifc
# 6548    tp118    JW63  male        14    500   .ifc
#
# [6549 rows x 9 columns]

# %% [markdown]
# # Load existing formant output files into a DataFrame

# %%
ifcdf = dir2df(ifcdir, addcols=['barename', 'dirname', 'ext'])
#covdf = dir2df(covdir, addcols=['barename', 'dirname', 'ext'])
#acdf = dir2df(acdir, addcols=['barename', 'dirname', 'ext'])
ifcdf
# Out:
# Empty DataFrame
# Columns: [dirname, relpath, fname, barename, ext]
# Index: []

# %% [markdown]
# ## Merge with data directory

# %%
ifcdf = wavdf.merge(
    ifcdf,
    left_on=['relpath', 'barename', 'ifcext'],
    right_on=['relpath', 'barename', 'ext'],
    suffixes=['', '_ifc'],
    how='left'
)
#covdf = wavdf.merge(
#    covdf,
#    left_on=['relpath', 'barename', 'covext'],
#    right_on=['relpath', 'barename', 'ext'],
#    suffixes=['', '_cov'],
#    how='left'
#)
#acdf = wavdf.merge(
#    acdf,
#    left_on=['relpath', 'barename', 'acext'],
#    right_on=['relpath', 'barename', 'ext'],
#    suffixes=['', '_ac'],
#    how='left'
#)
ifcdf
# Out:
#                                               dirname relpath        fname  \
# 0     /Users/ronald/Downloads/xray_microbeam_database    JW11    ta001.wav
# 1     /Users/ronald/Downloads/xray_microbeam_database    JW11    ta002.wav
# 2     /Users/ronald/Downloads/xray_microbeam_database    JW11    ta003.wav
# 3     /Users/ronald/Downloads/xray_microbeam_database    JW11    ta004.wav
# 4     /Users/ronald/Downloads/xray_microbeam_database    JW11    ta005.wav
# 5     /Users/ronald/Downloads/xray_microbeam_database    JW11    ta006.wav
# 6     /Users/ronald/Downloads/xray_microbeam_database    JW11    ta007.wav
# 7     /Users/ronald/Downloads/xray_microbeam_database    JW11    ta008.wav
# 8     /Users/ronald/Downloads/xray_microbeam_database    JW11    ta009.wav
# 9     /Users/ronald/Downloads/xray_microbeam_database    JW11    ta010.wav
# 10    /Users/ronald/Downloads/xray_microbeam_database    JW11    ta011.wav
# 11    /Users/ronald/Downloads/xray_microbeam_database    JW11    ta012.wav
# 12    /Users/ronald/Downloads/xray_microbeam_database    JW11    ta013.wav
# 13    /Users/ronald/Downloads/xray_microbeam_database    JW11    ta014.wav
# 14    /Users/ronald/Downloads/xray_microbeam_database    JW11    ta015.wav
# 15    /Users/ronald/Downloads/xray_microbeam_database    JW11    ta018.wav
# 16    /Users/ronald/Downloads/xray_microbeam_database    JW11    ta019.wav
# 17    /Users/ronald/Downloads/xray_microbeam_database    JW11    tp001.wav
# 18    /Users/ronald/Downloads/xray_microbeam_database    JW11    tp002.wav
# 19    /Users/ronald/Downloads/xray_microbeam_database    JW11    tp003.wav
# 20    /Users/ronald/Downloads/xray_microbeam_database    JW11    tp004.wav
# 21    /Users/ronald/Downloads/xray_microbeam_database    JW11    tp005.wav
# 22    /Users/ronald/Downloads/xray_microbeam_database    JW11    tp006.wav
# 23    /Users/ronald/Downloads/xray_microbeam_database    JW11    tp007.wav
# 24    /Users/ronald/Downloads/xray_microbeam_database    JW11    tp008.wav
# 25    /Users/ronald/Downloads/xray_microbeam_database    JW11    tp009.wav
# 26    /Users/ronald/Downloads/xray_microbeam_database    JW11    tp010.wav
# 27    /Users/ronald/Downloads/xray_microbeam_database    JW11    tp011.wav
# 28    /Users/ronald/Downloads/xray_microbeam_database    JW11    tp012.wav
# 29    /Users/ronald/Downloads/xray_microbeam_database    JW11    tp013.wav
# ...                                               ...     ...          ...
# 6519  /Users/ronald/Downloads/xray_microbeam_database    JW63    tp092.wav
# 6520  /Users/ronald/Downloads/xray_microbeam_database    JW63    tp093.wav
# 6521  /Users/ronald/Downloads/xray_microbeam_database    JW63    tp094.wav
# 6522  /Users/ronald/Downloads/xray_microbeam_database    JW63    tp095.wav
# 6523  /Users/ronald/Downloads/xray_microbeam_database    JW63    tp096.wav
# 6524  /Users/ronald/Downloads/xray_microbeam_database    JW63    tp097.wav
# 6525  /Users/ronald/Downloads/xray_microbeam_database    JW63    tp098.wav
# 6526  /Users/ronald/Downloads/xray_microbeam_database    JW63    tp099.wav
# 6527  /Users/ronald/Downloads/xray_microbeam_database    JW63    tp100.wav
# 6528  /Users/ronald/Downloads/xray_microbeam_database    JW63    tp101.wav
# 6529  /Users/ronald/Downloads/xray_microbeam_database    JW63    tp102.wav
# 6530  /Users/ronald/Downloads/xray_microbeam_database    JW63  tp102_2.wav
# 6531  /Users/ronald/Downloads/xray_microbeam_database    JW63    tp103.wav
# 6532  /Users/ronald/Downloads/xray_microbeam_database    JW63  tp103_2.wav
# 6533  /Users/ronald/Downloads/xray_microbeam_database    JW63  tp104_2.wav
# 6534  /Users/ronald/Downloads/xray_microbeam_database    JW63    tp105.wav
# 6535  /Users/ronald/Downloads/xray_microbeam_database    JW63    tp106.wav
# 6536  /Users/ronald/Downloads/xray_microbeam_database    JW63    tp107.wav
# 6537  /Users/ronald/Downloads/xray_microbeam_database    JW63    tp108.wav
# 6538  /Users/ronald/Downloads/xray_microbeam_database    JW63    tp109.wav
# 6539  /Users/ronald/Downloads/xray_microbeam_database    JW63    tp110.wav
# 6540  /Users/ronald/Downloads/xray_microbeam_database    JW63    tp111.wav
# 6541  /Users/ronald/Downloads/xray_microbeam_database    JW63    tp112.wav
# 6542  /Users/ronald/Downloads/xray_microbeam_database    JW63    tp113.wav
# 6543  /Users/ronald/Downloads/xray_microbeam_database    JW63    tp114.wav
# 6544  /Users/ronald/Downloads/xray_microbeam_database    JW63    tp115.wav
# 6545  /Users/ronald/Downloads/xray_microbeam_database    JW63    tp116.wav
# 6546  /Users/ronald/Downloads/xray_microbeam_database    JW63    tp117.wav
# 6547  /Users/ronald/Downloads/xray_microbeam_database    JW63  tp117_2.wav
# 6548  /Users/ronald/Downloads/xray_microbeam_database    JW63    tp118.wav
#
#      barename subject   sex lpc_order nom_f1 ifcext dirname_ifc fname_ifc  ext
# 0       ta001    JW11  male        14    500   .ifc         NaN       NaN  NaN
# 1       ta002    JW11  male        14    500   .ifc         NaN       NaN  NaN
# 2       ta003    JW11  male        14    500   .ifc         NaN       NaN  NaN
# 3       ta004    JW11  male        14    500   .ifc         NaN       NaN  NaN
# 4       ta005    JW11  male        14    500   .ifc         NaN       NaN  NaN
# 5       ta006    JW11  male        14    500   .ifc         NaN       NaN  NaN
# 6       ta007    JW11  male        14    500   .ifc         NaN       NaN  NaN
# 7       ta008    JW11  male        14    500   .ifc         NaN       NaN  NaN
# 8       ta009    JW11  male        14    500   .ifc         NaN       NaN  NaN
# 9       ta010    JW11  male        14    500   .ifc         NaN       NaN  NaN
# 10      ta011    JW11  male        14    500   .ifc         NaN       NaN  NaN
# 11      ta012    JW11  male        14    500   .ifc         NaN       NaN  NaN
# 12      ta013    JW11  male        14    500   .ifc         NaN       NaN  NaN
# 13      ta014    JW11  male        14    500   .ifc         NaN       NaN  NaN
# 14      ta015    JW11  male        14    500   .ifc         NaN       NaN  NaN
# 15      ta018    JW11  male        14    500   .ifc         NaN       NaN  NaN
# 16      ta019    JW11  male        14    500   .ifc         NaN       NaN  NaN
# 17      tp001    JW11  male        14    500   .ifc         NaN       NaN  NaN
# 18      tp002    JW11  male        14    500   .ifc         NaN       NaN  NaN
# 19      tp003    JW11  male        14    500   .ifc         NaN       NaN  NaN
# 20      tp004    JW11  male        14    500   .ifc         NaN       NaN  NaN
# 21      tp005    JW11  male        14    500   .ifc         NaN       NaN  NaN
# 22      tp006    JW11  male        14    500   .ifc         NaN       NaN  NaN
# 23      tp007    JW11  male        14    500   .ifc         NaN       NaN  NaN
# 24      tp008    JW11  male        14    500   .ifc         NaN       NaN  NaN
# 25      tp009    JW11  male        14    500   .ifc         NaN       NaN  NaN
# 26      tp010    JW11  male        14    500   .ifc         NaN       NaN  NaN
# 27      tp011    JW11  male        14    500   .ifc         NaN       NaN  NaN
# 28      tp012    JW11  male        14    500   .ifc         NaN       NaN  NaN
# 29      tp013    JW11  male        14    500   .ifc         NaN       NaN  NaN
# ...       ...     ...   ...       ...    ...    ...         ...       ...  ...
# 6519    tp092    JW63  male        14    500   .ifc         NaN       NaN  NaN
# 6520    tp093    JW63  male        14    500   .ifc         NaN       NaN  NaN
# 6521    tp094    JW63  male        14    500   .ifc         NaN       NaN  NaN
# 6522    tp095    JW63  male        14    500   .ifc         NaN       NaN  NaN
# 6523    tp096    JW63  male        14    500   .ifc         NaN       NaN  NaN
# 6524    tp097    JW63  male        14    500   .ifc         NaN       NaN  NaN
# 6525    tp098    JW63  male        14    500   .ifc         NaN       NaN  NaN
# 6526    tp099    JW63  male        14    500   .ifc         NaN       NaN  NaN
# 6527    tp100    JW63  male        14    500   .ifc         NaN       NaN  NaN
# 6528    tp101    JW63  male        14    500   .ifc         NaN       NaN  NaN
# 6529    tp102    JW63  male        14    500   .ifc         NaN       NaN  NaN
# 6530  tp102_2    JW63  male        14    500   .ifc         NaN       NaN  NaN
# 6531    tp103    JW63  male        14    500   .ifc         NaN       NaN  NaN
# 6532  tp103_2    JW63  male        14    500   .ifc         NaN       NaN  NaN
# 6533  tp104_2    JW63  male        14    500   .ifc         NaN       NaN  NaN
# 6534    tp105    JW63  male        14    500   .ifc         NaN       NaN  NaN
# 6535    tp106    JW63  male        14    500   .ifc         NaN       NaN  NaN
# 6536    tp107    JW63  male        14    500   .ifc         NaN       NaN  NaN
# 6537    tp108    JW63  male        14    500   .ifc         NaN       NaN  NaN
# 6538    tp109    JW63  male        14    500   .ifc         NaN       NaN  NaN
# 6539    tp110    JW63  male        14    500   .ifc         NaN       NaN  NaN
# 6540    tp111    JW63  male        14    500   .ifc         NaN       NaN  NaN
# 6541    tp112    JW63  male        14    500   .ifc         NaN       NaN  NaN
# 6542    tp113    JW63  male        14    500   .ifc         NaN       NaN  NaN
# 6543    tp114    JW63  male        14    500   .ifc         NaN       NaN  NaN
# 6544    tp115    JW63  male        14    500   .ifc         NaN       NaN  NaN
# 6545    tp116    JW63  male        14    500   .ifc         NaN       NaN  NaN
# 6546    tp117    JW63  male        14    500   .ifc         NaN       NaN  NaN
# 6547  tp117_2    JW63  male        14    500   .ifc         NaN       NaN  NaN
# 6548    tp118    JW63  male        14    500   .ifc         NaN       NaN  NaN
#
# [6549 rows x 12 columns]

# %% [markdown]
# ## Find missing formant output files
#
# We expect to find an '.ifc' file for every '.wav' file in the data directory. The preceding merge inserts a NaN value into the `fname_ifc` column wherever a '.wav' file does not have a corresponding '.ifc' file.

# %%
missingifc = ifcdf[ifcdf.fname_ifc.isna()]
missingifc.dirname_ifc = ifcdir
missingifc.fname_ifc = missingifc.barename + missingifc.ifcext

#missingcov = covdf[covdf.fname_cov.isna()]
#missingcov.dirname_cov = covdir
#missingcov.fname_cov = missingcov.barename + missingcov.covext

#missingac = acdf[acdf.fname_ac.isna()]
#missingac.dirname_ac = acdir
#missingac.fname_ac = missingac.barename + missingac.acext

missingifc
# Out:
#                                               dirname relpath        fname  \
# 0     /Users/ronald/Downloads/xray_microbeam_database    JW11    ta001.wav
# 1     /Users/ronald/Downloads/xray_microbeam_database    JW11    ta002.wav
# 2     /Users/ronald/Downloads/xray_microbeam_database    JW11    ta003.wav
# 3     /Users/ronald/Downloads/xray_microbeam_database    JW11    ta004.wav
# 4     /Users/ronald/Downloads/xray_microbeam_database    JW11    ta005.wav
# 5     /Users/ronald/Downloads/xray_microbeam_database    JW11    ta006.wav
# 6     /Users/ronald/Downloads/xray_microbeam_database    JW11    ta007.wav
# 7     /Users/ronald/Downloads/xray_microbeam_database    JW11    ta008.wav
# 8     /Users/ronald/Downloads/xray_microbeam_database    JW11    ta009.wav
# 9     /Users/ronald/Downloads/xray_microbeam_database    JW11    ta010.wav
# 10    /Users/ronald/Downloads/xray_microbeam_database    JW11    ta011.wav
# 11    /Users/ronald/Downloads/xray_microbeam_database    JW11    ta012.wav
# 12    /Users/ronald/Downloads/xray_microbeam_database    JW11    ta013.wav
# 13    /Users/ronald/Downloads/xray_microbeam_database    JW11    ta014.wav
# 14    /Users/ronald/Downloads/xray_microbeam_database    JW11    ta015.wav
# 15    /Users/ronald/Downloads/xray_microbeam_database    JW11    ta018.wav
# 16    /Users/ronald/Downloads/xray_microbeam_database    JW11    ta019.wav
# 17    /Users/ronald/Downloads/xray_microbeam_database    JW11    tp001.wav
# 18    /Users/ronald/Downloads/xray_microbeam_database    JW11    tp002.wav
# 19    /Users/ronald/Downloads/xray_microbeam_database    JW11    tp003.wav
# 20    /Users/ronald/Downloads/xray_microbeam_database    JW11    tp004.wav
# 21    /Users/ronald/Downloads/xray_microbeam_database    JW11    tp005.wav
# 22    /Users/ronald/Downloads/xray_microbeam_database    JW11    tp006.wav
# 23    /Users/ronald/Downloads/xray_microbeam_database    JW11    tp007.wav
# 24    /Users/ronald/Downloads/xray_microbeam_database    JW11    tp008.wav
# 25    /Users/ronald/Downloads/xray_microbeam_database    JW11    tp009.wav
# 26    /Users/ronald/Downloads/xray_microbeam_database    JW11    tp010.wav
# 27    /Users/ronald/Downloads/xray_microbeam_database    JW11    tp011.wav
# 28    /Users/ronald/Downloads/xray_microbeam_database    JW11    tp012.wav
# 29    /Users/ronald/Downloads/xray_microbeam_database    JW11    tp013.wav
# ...                                               ...     ...          ...
# 6519  /Users/ronald/Downloads/xray_microbeam_database    JW63    tp092.wav
# 6520  /Users/ronald/Downloads/xray_microbeam_database    JW63    tp093.wav
# 6521  /Users/ronald/Downloads/xray_microbeam_database    JW63    tp094.wav
# 6522  /Users/ronald/Downloads/xray_microbeam_database    JW63    tp095.wav
# 6523  /Users/ronald/Downloads/xray_microbeam_database    JW63    tp096.wav
# 6524  /Users/ronald/Downloads/xray_microbeam_database    JW63    tp097.wav
# 6525  /Users/ronald/Downloads/xray_microbeam_database    JW63    tp098.wav
# 6526  /Users/ronald/Downloads/xray_microbeam_database    JW63    tp099.wav
# 6527  /Users/ronald/Downloads/xray_microbeam_database    JW63    tp100.wav
# 6528  /Users/ronald/Downloads/xray_microbeam_database    JW63    tp101.wav
# 6529  /Users/ronald/Downloads/xray_microbeam_database    JW63    tp102.wav
# 6530  /Users/ronald/Downloads/xray_microbeam_database    JW63  tp102_2.wav
# 6531  /Users/ronald/Downloads/xray_microbeam_database    JW63    tp103.wav
# 6532  /Users/ronald/Downloads/xray_microbeam_database    JW63  tp103_2.wav
# 6533  /Users/ronald/Downloads/xray_microbeam_database    JW63  tp104_2.wav
# 6534  /Users/ronald/Downloads/xray_microbeam_database    JW63    tp105.wav
# 6535  /Users/ronald/Downloads/xray_microbeam_database    JW63    tp106.wav
# 6536  /Users/ronald/Downloads/xray_microbeam_database    JW63    tp107.wav
# 6537  /Users/ronald/Downloads/xray_microbeam_database    JW63    tp108.wav
# 6538  /Users/ronald/Downloads/xray_microbeam_database    JW63    tp109.wav
# 6539  /Users/ronald/Downloads/xray_microbeam_database    JW63    tp110.wav
# 6540  /Users/ronald/Downloads/xray_microbeam_database    JW63    tp111.wav
# 6541  /Users/ronald/Downloads/xray_microbeam_database    JW63    tp112.wav
# 6542  /Users/ronald/Downloads/xray_microbeam_database    JW63    tp113.wav
# 6543  /Users/ronald/Downloads/xray_microbeam_database    JW63    tp114.wav
# 6544  /Users/ronald/Downloads/xray_microbeam_database    JW63    tp115.wav
# 6545  /Users/ronald/Downloads/xray_microbeam_database    JW63    tp116.wav
# 6546  /Users/ronald/Downloads/xray_microbeam_database    JW63    tp117.wav
# 6547  /Users/ronald/Downloads/xray_microbeam_database    JW63  tp117_2.wav
# 6548  /Users/ronald/Downloads/xray_microbeam_database    JW63    tp118.wav
#
#      barename subject   sex lpc_order nom_f1 ifcext  \
# 0       ta001    JW11  male        14    500   .ifc
# 1       ta002    JW11  male        14    500   .ifc
# 2       ta003    JW11  male        14    500   .ifc
# 3       ta004    JW11  male        14    500   .ifc
# 4       ta005    JW11  male        14    500   .ifc
# 5       ta006    JW11  male        14    500   .ifc
# 6       ta007    JW11  male        14    500   .ifc
# 7       ta008    JW11  male        14    500   .ifc
# 8       ta009    JW11  male        14    500   .ifc
# 9       ta010    JW11  male        14    500   .ifc
# 10      ta011    JW11  male        14    500   .ifc
# 11      ta012    JW11  male        14    500   .ifc
# 12      ta013    JW11  male        14    500   .ifc
# 13      ta014    JW11  male        14    500   .ifc
# 14      ta015    JW11  male        14    500   .ifc
# 15      ta018    JW11  male        14    500   .ifc
# 16      ta019    JW11  male        14    500   .ifc
# 17      tp001    JW11  male        14    500   .ifc
# 18      tp002    JW11  male        14    500   .ifc
# 19      tp003    JW11  male        14    500   .ifc
# 20      tp004    JW11  male        14    500   .ifc
# 21      tp005    JW11  male        14    500   .ifc
# 22      tp006    JW11  male        14    500   .ifc
# 23      tp007    JW11  male        14    500   .ifc
# 24      tp008    JW11  male        14    500   .ifc
# 25      tp009    JW11  male        14    500   .ifc
# 26      tp010    JW11  male        14    500   .ifc
# 27      tp011    JW11  male        14    500   .ifc
# 28      tp012    JW11  male        14    500   .ifc
# 29      tp013    JW11  male        14    500   .ifc
# ...       ...     ...   ...       ...    ...    ...
# 6519    tp092    JW63  male        14    500   .ifc
# 6520    tp093    JW63  male        14    500   .ifc
# 6521    tp094    JW63  male        14    500   .ifc
# 6522    tp095    JW63  male        14    500   .ifc
# 6523    tp096    JW63  male        14    500   .ifc
# 6524    tp097    JW63  male        14    500   .ifc
# 6525    tp098    JW63  male        14    500   .ifc
# 6526    tp099    JW63  male        14    500   .ifc
# 6527    tp100    JW63  male        14    500   .ifc
# 6528    tp101    JW63  male        14    500   .ifc
# 6529    tp102    JW63  male        14    500   .ifc
# 6530  tp102_2    JW63  male        14    500   .ifc
# 6531    tp103    JW63  male        14    500   .ifc
# 6532  tp103_2    JW63  male        14    500   .ifc
# 6533  tp104_2    JW63  male        14    500   .ifc
# 6534    tp105    JW63  male        14    500   .ifc
# 6535    tp106    JW63  male        14    500   .ifc
# 6536    tp107    JW63  male        14    500   .ifc
# 6537    tp108    JW63  male        14    500   .ifc
# 6538    tp109    JW63  male        14    500   .ifc
# 6539    tp110    JW63  male        14    500   .ifc
# 6540    tp111    JW63  male        14    500   .ifc
# 6541    tp112    JW63  male        14    500   .ifc
# 6542    tp113    JW63  male        14    500   .ifc
# 6543    tp114    JW63  male        14    500   .ifc
# 6544    tp115    JW63  male        14    500   .ifc
# 6545    tp116    JW63  male        14    500   .ifc
# 6546    tp117    JW63  male        14    500   .ifc
# 6547  tp117_2    JW63  male        14    500   .ifc
# 6548    tp118    JW63  male        14    500   .ifc
#
#                                     dirname_ifc    fname_ifc  ext
# 0     /Users/ronald/Downloads/xray_formants_ifc    ta001.ifc  NaN
# 1     /Users/ronald/Downloads/xray_formants_ifc    ta002.ifc  NaN
# 2     /Users/ronald/Downloads/xray_formants_ifc    ta003.ifc  NaN
# 3     /Users/ronald/Downloads/xray_formants_ifc    ta004.ifc  NaN
# 4     /Users/ronald/Downloads/xray_formants_ifc    ta005.ifc  NaN
# 5     /Users/ronald/Downloads/xray_formants_ifc    ta006.ifc  NaN
# 6     /Users/ronald/Downloads/xray_formants_ifc    ta007.ifc  NaN
# 7     /Users/ronald/Downloads/xray_formants_ifc    ta008.ifc  NaN
# 8     /Users/ronald/Downloads/xray_formants_ifc    ta009.ifc  NaN
# 9     /Users/ronald/Downloads/xray_formants_ifc    ta010.ifc  NaN
# 10    /Users/ronald/Downloads/xray_formants_ifc    ta011.ifc  NaN
# 11    /Users/ronald/Downloads/xray_formants_ifc    ta012.ifc  NaN
# 12    /Users/ronald/Downloads/xray_formants_ifc    ta013.ifc  NaN
# 13    /Users/ronald/Downloads/xray_formants_ifc    ta014.ifc  NaN
# 14    /Users/ronald/Downloads/xray_formants_ifc    ta015.ifc  NaN
# 15    /Users/ronald/Downloads/xray_formants_ifc    ta018.ifc  NaN
# 16    /Users/ronald/Downloads/xray_formants_ifc    ta019.ifc  NaN
# 17    /Users/ronald/Downloads/xray_formants_ifc    tp001.ifc  NaN
# 18    /Users/ronald/Downloads/xray_formants_ifc    tp002.ifc  NaN
# 19    /Users/ronald/Downloads/xray_formants_ifc    tp003.ifc  NaN
# 20    /Users/ronald/Downloads/xray_formants_ifc    tp004.ifc  NaN
# 21    /Users/ronald/Downloads/xray_formants_ifc    tp005.ifc  NaN
# 22    /Users/ronald/Downloads/xray_formants_ifc    tp006.ifc  NaN
# 23    /Users/ronald/Downloads/xray_formants_ifc    tp007.ifc  NaN
# 24    /Users/ronald/Downloads/xray_formants_ifc    tp008.ifc  NaN
# 25    /Users/ronald/Downloads/xray_formants_ifc    tp009.ifc  NaN
# 26    /Users/ronald/Downloads/xray_formants_ifc    tp010.ifc  NaN
# 27    /Users/ronald/Downloads/xray_formants_ifc    tp011.ifc  NaN
# 28    /Users/ronald/Downloads/xray_formants_ifc    tp012.ifc  NaN
# 29    /Users/ronald/Downloads/xray_formants_ifc    tp013.ifc  NaN
# ...                                         ...          ...  ...
# 6519  /Users/ronald/Downloads/xray_formants_ifc    tp092.ifc  NaN
# 6520  /Users/ronald/Downloads/xray_formants_ifc    tp093.ifc  NaN
# 6521  /Users/ronald/Downloads/xray_formants_ifc    tp094.ifc  NaN
# 6522  /Users/ronald/Downloads/xray_formants_ifc    tp095.ifc  NaN
# 6523  /Users/ronald/Downloads/xray_formants_ifc    tp096.ifc  NaN
# 6524  /Users/ronald/Downloads/xray_formants_ifc    tp097.ifc  NaN
# 6525  /Users/ronald/Downloads/xray_formants_ifc    tp098.ifc  NaN
# 6526  /Users/ronald/Downloads/xray_formants_ifc    tp099.ifc  NaN
# 6527  /Users/ronald/Downloads/xray_formants_ifc    tp100.ifc  NaN
# 6528  /Users/ronald/Downloads/xray_formants_ifc    tp101.ifc  NaN
# 6529  /Users/ronald/Downloads/xray_formants_ifc    tp102.ifc  NaN
# 6530  /Users/ronald/Downloads/xray_formants_ifc  tp102_2.ifc  NaN
# 6531  /Users/ronald/Downloads/xray_formants_ifc    tp103.ifc  NaN
# 6532  /Users/ronald/Downloads/xray_formants_ifc  tp103_2.ifc  NaN
# 6533  /Users/ronald/Downloads/xray_formants_ifc  tp104_2.ifc  NaN
# 6534  /Users/ronald/Downloads/xray_formants_ifc    tp105.ifc  NaN
# 6535  /Users/ronald/Downloads/xray_formants_ifc    tp106.ifc  NaN
# 6536  /Users/ronald/Downloads/xray_formants_ifc    tp107.ifc  NaN
# 6537  /Users/ronald/Downloads/xray_formants_ifc    tp108.ifc  NaN
# 6538  /Users/ronald/Downloads/xray_formants_ifc    tp109.ifc  NaN
# 6539  /Users/ronald/Downloads/xray_formants_ifc    tp110.ifc  NaN
# 6540  /Users/ronald/Downloads/xray_formants_ifc    tp111.ifc  NaN
# 6541  /Users/ronald/Downloads/xray_formants_ifc    tp112.ifc  NaN
# 6542  /Users/ronald/Downloads/xray_formants_ifc    tp113.ifc  NaN
# 6543  /Users/ronald/Downloads/xray_formants_ifc    tp114.ifc  NaN
# 6544  /Users/ronald/Downloads/xray_formants_ifc    tp115.ifc  NaN
# 6545  /Users/ronald/Downloads/xray_formants_ifc    tp116.ifc  NaN
# 6546  /Users/ronald/Downloads/xray_formants_ifc    tp117.ifc  NaN
# 6547  /Users/ronald/Downloads/xray_formants_ifc  tp117_2.ifc  NaN
# 6548  /Users/ronald/Downloads/xray_formants_ifc    tp118.ifc  NaN
#
# [6549 rows x 12 columns]

# %% [markdown]
# ## Define analysis functions

# %%
def run_ifcformant(row, errors='raise'):
    '''Run ifcformant.'''
    try:
        subprocess.check_call([
            "ifcformant",
            "--speaker", row.sex,
            "--print-header",
            "--output", os.path.join(row.dirname_ifc, row.relpath, row.fname_ifc),
            os.path.join(row.dirname, row.relpath, row.fname)
        ])
    except subprocess.CalledProcessError as e:
        if errors == 'ignore':
            pass
        else:
            raise e

def run_formant_cov(row, errors='raise'):
    '''Run ESPS formant command with covariance settings.'''
    wdur = "0.025"
    try:
        subprocess.check_call([
            "formant",
            "-o", row.lpc_order,
            "-N", row.nom_f1,
            "-t1",
            "-w", wdur,
            "-O", os.path.join(row.dirname_cov, row.relpath),
            os.path.join(row.dirname, row.relpath, row.fname)
        ])
    except subprocess.CalledProcessError as e:
        if errors == 'ignore':
            pass
        else:
            raise e

def run_formant_ac(row, errors='raise'):
    '''Run ESPS formant command with autocorrelation settings.'''
    wdur = "0.049"
    subprocess.run(["formant","-o",str(order), "-N",str(nom_f1), "-t0","-w",str(wdur), soundfile],cwd=root)
    try:
        subprocess.check_call([
            "formant",
            "-o", row.lpc_order,
            "-N", row.nom_f1,
            "-t0",
            "-w", wdur,
            "-O", os.path.join(row.dirname_ac, row.relpath),
            os.path.join(row.dirname, row.relpath, row.fname)
        ])
    except subprocess.CalledProcessError as e:
        if errors == 'ignore':
            pass
        else:
            raise e

# %%
#index=0.10*np.arange(len(d)), 
f = EspsFea('/Users/ronald/Downloads/xray_formants_ac/syba_di.fb')
d = f.get_data()
pd.DataFrame.from_records(d.tolist(), columns=['f1', 'f2', 'f3', 'f4', 'bw1', 'bw2', 'bw3', 'bw4'])
# Out:
# 8

# %%
fbdf = fb2df('/Users/ronald/Downloads/xray_formants_ac/syba_di.fb', step=0.010)
fbdf
# Out:
#          t1           f1           f2           f3           f4          bw1  \
# 0      0.00   748.775536  1676.143784  3271.790973  3993.814557   200.715158
# 1      0.01  1325.861552  3499.634595  3561.345489  3499.634595   464.116803
# 2      0.02  1320.114658  2130.588354  3561.345489  4719.852502   509.196019
# 3      0.03   216.069013  1558.454221  2833.607805  3770.130892   333.463417
# 4      0.04    66.481432  1388.135893  3137.876954  3906.246691   407.456662
# 5      0.05  1389.779935  2160.531302  3109.417449  3996.506962  1697.052156
# 6      0.06  1086.079082  2135.775982  2891.133427  3889.785375   885.021126
# 7      0.07  1096.585509  2326.764951  3633.013769  4399.733808   887.141971
# 8      0.08  1005.039576  2252.792991  3099.128189  4345.855490   892.054812
# 9      0.09   241.780083  2275.134593  3796.830547  4323.858983   488.996261
# 10     0.10   481.183037  1981.375252  2735.761672  4412.076128   514.921157
# 11     0.11   423.969150  1870.473123  2640.356464  4403.402843   267.192630
# 12     0.12   308.633349  1759.684922  2705.272737  3778.397207   388.488316
# 13     0.13    97.808407  1126.541761  2107.884404  3679.721562   429.743747
# 14     0.14   693.846402  1763.892809  2671.814513  4486.659668   434.881374
# 15     0.15   502.704746  1686.904540  2405.021139  3369.943970   688.792855
# 16     0.16   451.832831  1567.960350  2274.235636  3990.084630  1505.207733
# 17     0.17   242.650047  1760.967452  2640.612001  3579.869086   540.062993
# 18     0.18   413.485868  1696.839492  2465.344797  4047.392088   684.895615
# 19     0.19   416.739015  1667.791087  2274.017939  4050.523115   349.002441
# 20     0.20   285.224614  1654.294600  2507.053234  3142.225714   367.172553
# 21     0.21   598.722059  1656.399847  2352.154534  3210.008395   603.522620
# 22     0.22   644.635900  1692.550775  2366.981110  3202.955855   567.142418
# 23     0.23   629.436865  1643.294109  2479.086289  3143.674214   310.767919
# 24     0.24   154.841400  1656.348199  2317.137741  3221.437878   594.206138
# 25     0.25   646.462545  1615.960744  2387.975101  3197.370631   431.197673
# 26     0.26   698.123902  1668.327429  2480.986010  3300.137903   527.529354
# 27     0.27   611.948688  1688.946497  2660.035574  3436.788023   647.443613
# 28     0.28   664.231082  1663.195551  2443.142633  3309.937870   507.961881
# 29     0.29   794.051329  1584.124555  2356.763230  3332.935356   923.582721
# ...     ...          ...          ...          ...          ...          ...
# 2233  22.33   292.659508  2133.020203  2677.601745  3236.521347    78.571742
# 2234  22.34   288.125910  2123.681726  2635.818129  3248.509469    83.830764
# 2235  22.35   299.617186  2111.470500  2614.040745  3248.699684    73.763676
# 2236  22.36   298.525640  2120.725381  2618.557660  3232.387394    71.722450
# 2237  22.37   302.331514  2122.965520  2640.535682  3248.593600    69.047900
# 2238  22.38   307.615929  2107.155479  2683.068180  3273.143240    57.989981
# 2239  22.39   299.232041  2116.917483  2671.268646  3282.347226    62.671404
# 2240  22.40   304.280983  2152.560006  2692.385901  3259.607268    55.048127
# 2241  22.41   305.741321  2141.610040  2694.945562  3283.373384    57.614587
# 2242  22.42   308.762470  2148.303431  2638.159185  3258.314149    52.985722
# 2243  22.43   313.893330  2175.424647  2697.337346  3295.353654    52.367100
# 2244  22.44   330.589074  2140.587156  2767.511442  3319.480782    45.987354
# 2245  22.45   331.284361  2150.023432  2567.381658  3349.591568    51.931027
# 2246  22.46   330.961425  2186.738443  2604.029316  3207.087445    65.295522
# 2247  22.47   331.331057  2150.417695  2563.091158  3230.382710    63.367721
# 2248  22.48   327.243718  2147.910631  2577.742436  3285.837840    69.313486
# 2249  22.49   329.270611  2139.543097  2548.130467  3340.229568    76.889250
# 2250  22.50   327.384776  2159.340280  2563.847162  3385.187609   124.039714
# 2251  22.51   291.859223  2096.899172  2383.861639  3329.948757   116.731214
# 2252  22.52   222.559251  2280.505843  3257.950892  4248.193507   164.152654
# 2253  22.53   104.444205  2183.514462  2662.194818  3663.297247    69.325400
# 2254  22.54   104.188838  1370.544534  2295.768575  3613.487821    57.623792
# 2255  22.55    88.703109  2399.805503  3540.998370  4502.779504   220.431572
# 2256  22.56  1083.584352  2079.849560  2807.715945  3611.355670  1572.251971
# 2257  22.57   117.228587  1282.393991  2309.021500  3536.237099   237.649937
# 2258  22.58   688.767326  1857.530909  2767.817996  3737.609645   687.344442
# 2259  22.59   163.694542  1814.654007  2736.360286  3624.908019   365.970632
# 2260  22.60    96.701688  1553.134688  3526.327136  4391.448260   611.040719
# 2261  22.61   236.978860  1600.579339  3580.766022  4541.588770   452.851539
# 2262  22.62   194.344000  1472.463357  2445.506622  3753.320710   410.595262
#
#               bw2         bw3          bw4
# 0      541.653987  231.539310   451.179899
# 1     1175.167209  599.266338  1175.167209
# 2      722.811535  599.266338   651.670560
# 3      594.334566  613.061859   411.481336
# 4      378.132720  568.367027   659.455810
# 5      691.212223  797.234775   478.799744
# 6      453.480333  552.336940   413.152531
# 7      429.924268  451.666941   255.183819
# 8      322.679756  750.529722   245.666225
# 9      663.437109  569.768945   228.018557
# 10     395.573732  714.351791   316.121658
# 11     317.577480  655.537530   275.269283
# 12     235.836293  382.234571   468.838385
# 13     899.889231  404.325878   296.972204
# 14     345.638998  588.351598   456.556537
# 15     383.881728  466.335851   303.940620
# 16     757.958147  578.508108   587.368586
# 17     221.842261  553.494130   240.379942
# 18     194.771964  552.655465   628.456847
# 19     216.911733  393.312236   491.029413
# 20     363.379126  713.870329   816.686311
# 21     510.037247  436.763420   418.353969
# 22     294.915681  614.754845   322.949032
# 23      70.305766  251.791609   261.028823
# 24     198.057251  788.689625   338.954539
# 25     186.298440  466.362020   329.255250
# 26     204.114449  531.314728   468.591954
# 27     262.701913  553.901086   425.895473
# 28     102.084660  444.152416   307.209627
# 29     401.242831  439.208254   509.377379
# ...           ...         ...          ...
# 2233   122.763113  199.103052   160.962967
# 2234   113.952418  184.999543   155.588162
# 2235   116.228858  191.424003   150.227095
# 2236   147.698663  279.444807   228.024292
# 2237   104.295750  249.781019   136.551199
# 2238   132.688810  252.758834   176.269806
# 2239   115.302632  177.703697   209.373698
# 2240    60.789437  142.456001    89.520947
# 2241    95.067869  147.677965    81.823051
# 2242   105.245479  224.985968   142.129192
# 2243   162.264504  222.785466   132.775366
# 2244   145.436051  238.239497   140.964266
# 2245   104.464827  221.927404   232.496471
# 2246    72.704839  224.795684   407.481861
# 2247    69.209414  193.887286   232.104041
# 2248    73.892923  224.795141   179.392136
# 2249    88.619009  210.428306   131.574884
# 2250    83.843035  206.411049   107.126966
# 2251   278.642940  353.681499   271.297880
# 2252   297.740794  409.127496   601.106448
# 2253   423.346674  336.890838   332.758239
# 2254   854.694027  589.812763   524.493527
# 2255   335.699369  194.730258   424.183919
# 2256   537.609622  976.770806   533.614218
# 2257   434.491821  490.780753   570.359775
# 2258   279.670353  444.726337   573.440879
# 2259   287.745661  507.493582   378.235839
# 2260   654.408231  366.890469   335.895364
# 2261   593.822740  364.015566   506.979600
# 2262   347.674741  366.129154   541.797548
#
# [2263 rows x 9 columns]
